# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt 
from sklearn.preprocessing import StandardScaler
crimedata = pd.read_csv("crime_data.csv")
crimedata
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %% [markdown]
# We can see that the first column is unnamed here and so we will rename it with Location

# %%
crimedata.rename(columns = {crimedata.columns[0]:"Location"},inplace = True)

# %%
crimedata
# Out:
#           Location  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
crimedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  50 non-null     object
#  1   Murder    50 non-null     float64
#  2   Assault   50 non-null     int64
#  3   UrbanPop  50 non-null     int64
#  4   Rape      50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# <b>no null values are present</b>

# %%
crimedata[crimedata.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Location, Murder, Assault, UrbanPop, Rape, cluster]
# Index: []

# %% [markdown]
# <b>no duplicate values are present</b>

# %%
crimedata.corr();

# %% [markdown]
# <b>We need to normalize our data as for each feature the data will be in different scale and will affect our output if we use it directly without normalizing</b>

# %%
from sklearn.preprocessing import MinMaxScaler
trans = MinMaxScaler()
data = pd.DataFrame(trans.fit_transform(crimedata.iloc[:,1:]))
data
# Out:
#            0         1         2         3     4
# 0   0.746988  0.654110  0.440678  0.359173  0.75
# 1   0.554217  0.746575  0.271186  0.961240  1.00
# 2   0.439759  0.852740  0.813559  0.612403  0.25
# 3   0.481928  0.496575  0.305085  0.315245  0.00
# 4   0.493976  0.791096  1.000000  0.860465  0.25
# 5   0.427711  0.544521  0.779661  0.811370  0.25
# 6   0.150602  0.222603  0.762712  0.098191  0.00
# 7   0.307229  0.660959  0.677966  0.219638  0.00
# 8   0.879518  0.993151  0.813559  0.635659  0.25
# 9   1.000000  0.568493  0.474576  0.478036  0.75
# 10  0.271084  0.003425  0.864407  0.333333  0.00
# 11  0.108434  0.256849  0.372881  0.178295  0.50
# 12  0.578313  0.698630  0.864407  0.431525  0.25
# 13  0.385542  0.232877  0.559322  0.354005  0.00
# 14  0.084337  0.037671  0.423729  0.103359  0.50
# 15  0.313253  0.239726  0.576271  0.276486  0.00
# 16  0.536145  0.219178  0.338983  0.232558  0.00
# 17  0.879518  0.698630  0.576271  0.385013  0.75
# ...

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch # for creating dendrogram 
z = linkage(data, method="complete",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(
    z
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering 
h_complete = AgglomerativeClustering(n_clusters=5, linkage='complete',affinity = "euclidean").fit(data) 

cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
crimedata['cluster']=cluster_labels # creating a  new column and assigning it to new column 
crimedata.sort_values(by=['cluster'])
# Out:
#           Location  Murder  Assault  UrbanPop  Rape  cluster
# 49         Wyoming     6.8      161        60  15.6        0
# 20   Massachusetts     4.4      149        85  16.3        0
# 29      New Jersey     7.4      159        89  18.8        0
# 16        Kentucky     9.7      109        52  16.3        0
# 15          Kansas     6.0      115        66  18.0        0
# 34            Ohio     7.3      120        75  21.4        0
# 13         Indiana     7.2      113        65  21.0        0
# 35        Oklahoma     6.6      151        68  20.0        0
# 22       Minnesota     2.7       72        66  14.9        0
# 10          Hawaii     5.3       46        83  20.2        0
# 36          Oregon     4.9      159        67  29.3        0
# 38    Rhode Island     3.4      174        87   8.3        0
# 7         Delaware     5.9      238        72  15.8        0
# 6      Connecticut     3.3      110        77  11.1        0
# ...

# %%
crimedata.iloc[:,1:].groupby(crimedata.cluster).mean()
# Out:
#             Murder     Assault   UrbanPop       Rape  cluster
# cluster
# 0         5.715000  132.300000  70.800000  18.100000      0.0
# 1        10.883333  256.916667  78.333333  32.250000      1.0
# 2         3.180000   78.700000  49.300000  11.630000      2.0
# 3        14.671429  251.285714  54.285714  21.685714      3.0
# 4        10.000000  263.000000  48.000000  44.500000      4.0

# %% [markdown]
# ## Inferences:
#    ### 1. Cluster 4 has only one state i.e. Alaska but still has significant rate of crime.
#    ### 2. Cluster 2 has minimum rate of overall crime. It has total 10 states.
